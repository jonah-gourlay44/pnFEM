# %%
import sys
sys.path.insert(0, '../src')
import numpy as np
from constants import *
from mesh import Mesh
from physics import Physics
from diode_fem import DiodeFEM
import matplotlib.pyplot as plt

# %%
mesh = Mesh(6, 0.2)
fem = DiodeFEM(mesh)

fem.solve(0, 0.001, 1e-2)
fem.plot()
